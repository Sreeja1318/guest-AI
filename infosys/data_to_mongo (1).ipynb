# %%
pip install pymongo
# Out:
# ...
#
# ...

# %%
from pymongo import MongoClient
import pandas as pd

# %%
client = MongoClient("mongodb+srv://sreejachiluveru744:sreeja13@cluster0.urhcm.mongodb.net/hotel_guests?retryWrites=true&w=majority"
)

db = client["hotel_guests"]

# %%
df = pd.read_excel('C:\\Users\\LENOVO\\Downloads\\infosys\\dining_info.xlsx')

# %%
df
# Out:
#        Unnamed: 0  transaction_id  customer_id Preferred Cusine   age  \
# 0             0.0       3594217.0         91.0     South Indian  31.0
# 1             1.0      10163344.0         92.0     South Indian  21.0
# 2             2.0      12292432.0         93.0     North Indian  48.0
# 3             3.0      13757710.0         94.0     South Indian  25.0
# 4             4.0      10762656.0         95.0     North Indian  22.0
# ...           ...             ...          ...              ...   ...
# 10003         NaN             NaN          NaN              NaN   NaN
# 10004         NaN             NaN          NaN              NaN   NaN
# 10005         NaN             NaN          NaN              NaN   NaN
# 10006         NaN             NaN          NaN              NaN   NaN
# 10007         NaN             NaN          NaN              NaN   NaN
#
#                   dish  Qty  price_for_1  number_of_stayers check_in_date  \
# ...

# %%
bookings_df = pd.read_excel("C:\\Users\\LENOVO\\Downloads\\infosys\\bookings_data.xlsx")  # Make sure the file is in the correct path
db.bookings.drop()  # Optional: remove existing entries to avoid duplicates
db.bookings.insert_many(bookings_df.to_dict(orient="records"))
print("Bookings data uploaded successfully.")
# Out:
# Bookings data uploaded successfully.

# %%
reviews_df = pd.read_excel("reviews_data.xlsx")  # Replace with actual reviews file
db.reviews.drop()  # Optional: clean previous entries
db.reviews.insert_many(reviews_df.to_dict(orient="records"))
print("Reviews data uploaded successfully.")
# Out:
# Reviews data uploaded successfully.

# %%
db["bookings"].insert_many(bookings_df.to_dict("records"))
# Out:
# InsertManyResult([ObjectId('67d5505c60646d4882a89210'), ObjectId('67d5505c60646d4882a89211'), ObjectId('67d5505c60646d4882a89212'), ObjectId('67d5505c60646d4882a89213'), ObjectId('67d5505c60646d4882a89214'), ObjectId('67d5505c60646d4882a89215'), ObjectId('67d5505c60646d4882a89216'), ObjectId('67d5505c60646d4882a89217'), ObjectId('67d5505c60646d4882a89218'), ObjectId('67d5505c60646d4882a89219'), ObjectId('67d5505c60646d4882a8921a'), ObjectId('67d5505c60646d4882a8921b'), ObjectId('67d5505c60646d4882a8921c'), ObjectId('67d5505c60646d4882a8921d'), ObjectId('67d5505c60646d4882a8921e'), ObjectId('67d5505c60646d4882a8921f'), ObjectId('67d5505c60646d4882a89220'), ObjectId('67d5505c60646d4882a89221'), ObjectId('67d5505c60646d4882a89222'), ObjectId('67d5505c60646d4882a89223'), ObjectId('67d5505c60646d4882a89224'), ObjectId('67d5505c60646d4882a89225')], acknowledged=True)

# %%
db["reviews"].insert_many(reviews_df.to_dict("records"))
# Out:
# InsertManyResult([ObjectId('67d550c860646d4882a89226'), ObjectId('67d550c860646d4882a89227'), ObjectId('67d550c860646d4882a89228'), ObjectId('67d550c860646d4882a89229'), ObjectId('67d550c860646d4882a8922a'), ObjectId('67d550c860646d4882a8922b'), ObjectId('67d550c860646d4882a8922c'), ObjectId('67d550c860646d4882a8922d'), ObjectId('67d550c860646d4882a8922e'), ObjectId('67d550c860646d4882a8922f'), ObjectId('67d550c860646d4882a89230'), ObjectId('67d550c860646d4882a89231'), ObjectId('67d550c860646d4882a89232'), ObjectId('67d550c860646d4882a89233'), ObjectId('67d550c860646d4882a89234'), ObjectId('67d550c860646d4882a89235'), ObjectId('67d550c860646d4882a89236'), ObjectId('67d550c860646d4882a89237'), ObjectId('67d550c860646d4882a89238'), ObjectId('67d550c860646d4882a89239'), ObjectId('67d550c860646d4882a8923a'), ObjectId('67d550c860646d4882a8923b'), ObjectId('67d550c860646d4882a8923c'), ObjectId('67d550c860646d4882a8923d'), ObjectId('67d550c860646d4882a8923e'), ObjectId('67d550c860646d4882a8
# ...

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
collection = db["dining_info"]

# %%
collection.insert_many(df.to_dict(orient="records"))
# Out:
# InsertManyResult([ObjectId('67bb3b1578a8da8ea017a5da'), ObjectId('67bb3b1578a8da8ea017a5db'), ObjectId('67bb3b1578a8da8ea017a5dc'), ObjectId('67bb3b1578a8da8ea017a5dd'), ObjectId('67bb3b1578a8da8ea017a5de'), ObjectId('67bb3b1578a8da8ea017a5df'), ObjectId('67bb3b1578a8da8ea017a5e0'), ObjectId('67bb3b1578a8da8ea017a5e1'), ObjectId('67bb3b1578a8da8ea017a5e2'), ObjectId('67bb3b1578a8da8ea017a5e3'), ObjectId('67bb3b1578a8da8ea017a5e4'), ObjectId('67bb3b1578a8da8ea017a5e5'), ObjectId('67bb3b1578a8da8ea017a5e6'), ObjectId('67bb3b1578a8da8ea017a5e7'), ObjectId('67bb3b1578a8da8ea017a5e8'), ObjectId('67bb3b1578a8da8ea017a5e9'), ObjectId('67bb3b1578a8da8ea017a5ea'), ObjectId('67bb3b1578a8da8ea017a5eb'), ObjectId('67bb3b1578a8da8ea017a5ec'), ObjectId('67bb3b1578a8da8ea017a5ed'), ObjectId('67bb3b1578a8da8ea017a5ee'), ObjectId('67bb3b1578a8da8ea017a5ef'), ObjectId('67bb3b1578a8da8ea017a5f0'), ObjectId('67bb3b1578a8da8ea017a5f1'), ObjectId('67bb3b1578a8da8ea017a5f2'), ObjectId('67bb3b1578a8da8ea017
# ...
